# %%
import pandas as pd 
path = "C:/Users/PRAKHAR/AppData/Local/Programs/Kaggle/Test.xlsx"
df = pd.read_excel(path)
print(df)
# Out:
#    S.no   A    B    C   D   E
# 0     1  15  100   25   1   2
# 1     2  20  150   50   3   4
# 2     3  25  200   75   5   6
# 3     4  30  250  100   7   8
# 4     5  35  300  125   9  10
# 5     6  40  350  150  11  12
# 6     7  45  400  175  13  14
# 7     8  50  450  200  15  16
# 8     9  15  500  225  17  18

# %%
import numpy as np
grp = df.groupby('A')
grp.aggregate(np.sum)
# grp.aggregate(sum)
# Out:
# C:\Users\PRAKHAR\AppData\Local\Temp\ipykernel_18048\3329677013.py:3: FutureWarning: The provided callable <function sum at 0x000001FD2D8A77E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#     S.no    B    C   D   E
# A
# 15    10  600  250  18  20
# 20     2  150   50   3   4
# 25     3  200   75   5   6
# 30     4  250  100   7   8
# 35     5  300  125   9  10
# 40     6  350  150  11  12
# 45     7  400  175  13  14
# 50     8  450  200  15  16

# %%
grp = df.groupby(['A','B'] , as_index = False)

grp.aggregate(np.sum)
# Out:
# C:\Users\PRAKHAR\AppData\Local\Temp\ipykernel_18048\1616691257.py:3: FutureWarning: The provided callable <function sum at 0x000001FD2D8A77E0> is currently using DataFrameGroupBy.sum. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "sum" instead.
#   grp.aggregate(np.sum)
#     A    B  S.no    C   D   E
# 0  15  100     1   25   1   2
# 1  15  500     9  225  17  18
# 2  20  150     2   50   3   4
# 3  25  200     3   75   5   6
# 4  30  250     4  100   7   8
# 5  35  300     5  125   9  10
# 6  40  350     6  150  11  12
# 7  45  400     7  175  13  14
# 8  50  450     8  200  15  16

# %%
grp.size()
# Out:
#     A    B  size
# 0  15  100     1
# 1  15  500     1
# 2  20  150     1
# 3  25  200     1
# 4  30  250     1
# 5  35  300     1
# 6  40  350     1
# 7  45  400     1
# 8  50  450     1

# %%
grp.count()
# Out:
#     A    B  S.no  C  D  E
# 0  15  100     1  1  1  1
# 1  15  500     1  1  1  1
# 2  20  150     1  1  1  1
# 3  25  200     1  1  1  1
# 4  30  250     1  1  1  1
# 5  35  300     1  1  1  1
# 6  40  350     1  1  1  1
# 7  45  400     1  1  1  1
# 8  50  450     1  1  1  1

# %%
# TO CREATE A NEW DATA FRAME

l = [['apple',1],['apple',2],['ball',1],['ball',1]]
df_10 = pd.DataFrame(l, columns=["A","B"])
print(df_10)
# Out:
#        A  B
# 0  apple  1
# 1  apple  2
# 2   ball  1
# 3   ball  1

# %%
df_10.groupby("A")["B"].nunique()
# Out:
# A
# apple    2
# ball     1
# Name: B, dtype: int64

# %%
df_20 = pd.DataFrame({'S.no' : [1,2,3,4,5] , 'A' : ['apple','ant','ankle','air','aura'] , 'B' : ['ball','basket','bucket','broom','bat'] , 'C' : ['cat','cake','car','cow','coat'] , 'D' : ['dog','duck','doll','deer','drum']})
print(df_20)
# Out:
#    S.no      A       B     C     D
# 0     1  apple    ball   cat   dog
# 1     2    ant  basket  cake  duck
# 2     3  ankle  bucket   car  doll
# 3     4    air   broom   cow  deer
# 4     5   aura     bat  coat  drum

# %%
# PIVOT

df_20.pivot(index = 'A' , columns = 'B' , values = 'C')
# Out:
# B     ball basket   bat broom bucket
# A
# air    NaN    NaN   NaN   cow    NaN
# ankle  NaN    NaN   NaN   NaN    car
# ant    NaN   cake   NaN   NaN    NaN
# apple  cat    NaN   NaN   NaN    NaN
# aura   NaN    NaN  coat   NaN    NaN

# %%
df_20.pivot(index = 'S.no' , columns = 'A' , values = ['B','C'])
# Out:
#           B                               C
# A       air   ankle     ant apple aura  air ankle   ant apple  aura
# S.no
# 1       NaN     NaN     NaN  ball  NaN  NaN   NaN   NaN   cat   NaN
# 2       NaN     NaN  basket   NaN  NaN  NaN   NaN  cake   NaN   NaN
# 3       NaN  bucket     NaN   NaN  NaN  NaN   car   NaN   NaN   NaN
# 4     broom     NaN     NaN   NaN  NaN  cow   NaN   NaN   NaN   NaN
# 5       NaN     NaN     NaN   NaN  bat  NaN   NaN   NaN   NaN  coat

# %%
# HEATMAP

import numpy as np
np.random.seed(0)
import seaborn as sns

uniform_data = np.random.rand(5,6)
print(uniform_data)
# Out:
# [[0.5488135  0.71518937 0.60276338 0.54488318 0.4236548  0.64589411]
#  [0.43758721 0.891773   0.96366276 0.38344152 0.79172504 0.52889492]
#  [0.56804456 0.92559664 0.07103606 0.0871293  0.0202184  0.83261985]
#  [0.77815675 0.87001215 0.97861834 0.79915856 0.46147936 0.78052918]
#  [0.11827443 0.63992102 0.14335329 0.94466892 0.52184832 0.41466194]]

# %%
heat_map = sns.heatmap(uniform_data)

# %%
heat_map = sns.heatmap(uniform_data , vmin = 0 , vmax = 1 )

# %%
normal_data = np.random.randn(6,6)
print(normal_data)
# Out:
# [[ 0.8644362  -0.74216502  2.26975462 -1.45436567  0.04575852 -0.18718385]
#  [ 1.53277921  1.46935877  0.15494743  0.37816252 -0.88778575 -1.98079647]
#  [-0.34791215  0.15634897  1.23029068  1.20237985 -0.38732682 -0.30230275]
#  [-1.04855297 -1.42001794 -1.70627019  1.9507754  -0.50965218 -0.4380743 ]
#  [-1.25279536  0.77749036 -1.61389785 -0.21274028 -0.89546656  0.3869025 ]
#  [-0.51080514 -1.18063218 -0.02818223  0.42833187  0.06651722  0.3024719 ]]

# %%
heat_map3 = sns.heatmap(normal_data , center = 0)

# %%
heat_map5 = sns.heatmap(flights_pivot , annot = True , fmt = "d")

# %%
flights = sns.load_dataset("flights")
flights_pivot = flights.pivot(index='month', columns='year', values='passengers')
sns.heatmap(flights_pivot)
# Out:
# <Axes: xlabel='year', ylabel='month'>

# %%
heat_map6 = sns.heatmap(flights_pivot , cmap = "YlGnBu")

# %%
heat_map7 = sns.heatmap(flights_pivot , cbar = False)

# %%
# CO-RELATION

# Positive corelation 
flights = sns.load_dataset("flights")
sns.regplot(x='passengers' , y = 'year' , data = flights)
# Out:
# <Axes: xlabel='passengers', ylabel='year'>

# %%
from scipy import stats
flights = sns.load_dataset("flights")
print(flights)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
pearson_correlation = stats.pearsonr(flights['year'] , flights['passengers'])
print(pearson_correlation)
# Out:
# PearsonRResult(statistic=np.float64(0.92182383529242), pvalue=np.float64(2.58104255191102e-60))
