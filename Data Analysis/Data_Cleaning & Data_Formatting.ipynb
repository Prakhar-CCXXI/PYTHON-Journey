# %%
import pandas as pd 
path = "C:/Users/PRAKHAR/AppData/Local/Programs/Kaggle/academic-Stress-level.xlsx"
df = pd.read_excel(path)
print(df)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
# 140         140  18/08/2025 22:40:14       undergraduate            NaN
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df.head(5)
# Out:
#    Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0           0  24/07/2025 22:05:39       undergraduate            4.0
# 1           1  24/07/2025 22:05:52       undergraduate            3.0
# 2           2  24/07/2025 22:06:39       undergraduate            1.0
# 3           3  24/07/2025 22:06:45       undergraduate            3.0
# 4           4  24/07/2025 22:08:06       undergraduate            3.0
#
#    Academic pressure from your home Study Environment  \
# 0                               5.0             Noisy
# 1                               4.0          Peaceful
# 2                               1.0          Peaceful
# 3                               2.0          Peaceful
# 4                               3.0          Peaceful
#
#           What coping strategy you use as a student?  \
# 0  Analyze the situation and handle it with intel...
# 1  Analyze the situation and handle it with intel...
# ...

# %%
headers = ["S.No","Date & Time","Highest Degree","PP No.","Academic Pressure form your home No.","SE","Strategy you use","Bad habit","Academic competition","Academic stress index"]
df.columns = headers
df.head(5)
# Out:
#    S.No          Date & Time Highest Degree  PP No.  \
# 0     0  24/07/2025 22:05:39  undergraduate     4.0
# 1     1  24/07/2025 22:05:52  undergraduate     3.0
# 2     2  24/07/2025 22:06:39  undergraduate     1.0
# 3     3  24/07/2025 22:06:45  undergraduate     3.0
# 4     4  24/07/2025 22:08:06  undergraduate     3.0
#
#    Academic Pressure form your home No.        SE  \
# 0                                   5.0     Noisy
# 1                                   4.0  Peaceful
# 2                                   1.0  Peaceful
# 3                                   2.0  Peaceful
# 4                                   3.0  Peaceful
#
#                                     Strategy you use Bad habit  \
# 0  Analyze the situation and handle it with intel...        No
# 1  Analyze the situation and handle it with intel...        No
# 2                   Social support (friends, family)        No
# 3  Analyze the situation and handle it with intel...        No
# ...

# %%
print(df)
# Out:
#      S.No          Date & Time Highest Degree  PP No.  \
# 0       0  24/07/2025 22:05:39  undergraduate     4.0
# 1       1  24/07/2025 22:05:52  undergraduate     3.0
# 2       2  24/07/2025 22:06:39  undergraduate     1.0
# 3       3  24/07/2025 22:06:45  undergraduate     3.0
# 4       4  24/07/2025 22:08:06  undergraduate     3.0
# ..    ...                  ...            ...     ...
# 136   136  18/08/2025 14:36:00  undergraduate     4.0
# 137   137  18/08/2025 17:13:52  undergraduate     3.0
# 138   138  18/08/2025 19:08:52  undergraduate     4.0
# 139   139  18/08/2025 22:40:13  undergraduate     4.0
# 140   140  18/08/2025 22:40:14  undergraduate     NaN
#
#      Academic Pressure form your home No.         SE  \
# 0                                     5.0      Noisy
# 1                                     4.0   Peaceful
# 2                                     1.0   Peaceful
# 3                                     2.0   Peaceful
# ...

# %%
df.tail(5)
# Out:
#      S.No          Date & Time Highest Degree  PP No.  \
# 136   136  18/08/2025 14:36:00  undergraduate     4.0
# 137   137  18/08/2025 17:13:52  undergraduate     3.0
# 138   138  18/08/2025 19:08:52  undergraduate     4.0
# 139   139  18/08/2025 22:40:13  undergraduate     4.0
# 140   140  18/08/2025 22:40:14  undergraduate     NaN
#
#      Academic Pressure form your home No.         SE  \
# 136                                   2.0  disrupted
# 137                                   3.0   Peaceful
# 138                                   5.0  disrupted
# 139                                   2.0   Peaceful
# 140                                   NaN  disrupted
#
#                                       Strategy you use Bad habit  \
# 136  Analyze the situation and handle it with intel...        No
# 137  Analyze the situation and handle it with intel...        No
# 138                   Social support (friends, family)        No
# ...

# %%
import pandas as pd 
path = "C:/Users/PRAKHAR/AppData/Local/Programs/Kaggle/academic-Stress-level.xlsx"
df = pd.read_excel(path)
print(df)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
# 140         140  18/08/2025 22:40:14       undergraduate            NaN
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
# 140         140  18/08/2025 22:40:14       undergraduate            NaN
#
#      Academic pressure from your home Study Environment  \
# 136                               2.0         disrupted
# 137                               3.0          Peaceful
# 138                               5.0         disrupted
# 139                               2.0          Peaceful
# 140                               NaN         disrupted
#
#             What coping strategy you use as a student?  \
# 136  Analyze the situation and handle it with intel...
# 137  Analyze the situation and handle it with intel...
# ...

# %%
df.drop([10],axis=0)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
# 140         140  18/08/2025 22:40:14       undergraduate            NaN
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df.drop([140],axis=0)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 135         135  17/08/2025 13:02:04       undergraduate            3.0
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
# 140         140  18/08/2025 22:40:14       undergraduate            NaN
#
#      Academic pressure from your home Study Environment  \
# 136                               2.0         disrupted
# 137                               3.0          Peaceful
# 138                               5.0         disrupted
# 139                               2.0          Peaceful
# 140                               NaN         disrupted
#
#             What coping strategy you use as a student?  \
# 136  Analyze the situation and handle it with intel...
# 137  Analyze the situation and handle it with intel...
# ...

# %%
df.dropna()
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 135         135  17/08/2025 13:02:04       undergraduate            3.0
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
import numpy as np 
df["Peer pressure"].replace(np.nan,22)
# Out:
# 0       4.0
# 1       3.0
# 2       1.0
# 3       3.0
# 4       3.0
#        ...
# 136     4.0
# 137     3.0
# 138     4.0
# 139     4.0
# 140    22.0
# Name: Peer pressure, Length: 141, dtype: float64

# %%
df["Academic pressure from your home"]=df["Academic pressure from your home"]/2
df.head(5)
# Out:
#    Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0           0  24/07/2025 22:05:39       undergraduate            4.0
# 1           1  24/07/2025 22:05:52       undergraduate            3.0
# 2           2  24/07/2025 22:06:39       undergraduate            1.0
# 3           3  24/07/2025 22:06:45       undergraduate            3.0
# 4           4  24/07/2025 22:08:06       undergraduate            3.0
#
#    Academic pressure from your home Study Environment  \
# 0                               2.5             Noisy
# 1                               2.0          Peaceful
# 2                               0.5          Peaceful
# 3                               1.0          Peaceful
# 4                               1.5          Peaceful
#
#           What coping strategy you use as a student?  \
# 0  Analyze the situation and handle it with intel...
# 1  Analyze the situation and handle it with intel...
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                                               int64
# Timestamp                                                               object
# Your Academic Stage                                                     object
# Peer pressure                                                          float64
# Academic pressure from your home                                       float64
# Study Environment                                                       object
# What coping strategy you use as a student?                              object
# Do you have any bad habits like smoking, drinking on a daily basis?     object
# What would you rate the academic  competition in your student life     float64
# Rate your academic stress index                                        float64
# dtype: object

# %%
print(df.isnull().sum)
# Out:
# <bound method DataFrame.sum of      Unnamed: 0  Timestamp  Your Academic Stage  Peer pressure  \
# 0         False      False                False          False
# 1         False      False                False          False
# 2         False      False                False          False
# 3         False      False                False          False
# 4         False      False                False          False
# ..          ...        ...                  ...            ...
# 136       False      False                False          False
# 137       False      False                False          False
# 138       False      False                False          False
# 139       False      False                False          False
# 140       False      False                False           True
#
#      Academic pressure from your home  Study Environment  \
# 0                               False              False
# 1                               False              False
# ...

# %%
df.tail(5)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
# 140         140  18/08/2025 22:40:14       undergraduate            NaN
#
#      Academic pressure from your home Study Environment  \
# 136                               1.0         disrupted
# 137                               1.5          Peaceful
# 138                               2.5         disrupted
# 139                               1.0          Peaceful
# 140                               NaN         disrupted
#
#             What coping strategy you use as a student?  \
# 136  Analyze the situation and handle it with intel...
# 137  Analyze the situation and handle it with intel...
# ...

# %%
df.drop([140],axis=0)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 135         135  17/08/2025 13:02:04       undergraduate            3.0
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df.dropna()
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 135         135  17/08/2025 13:02:04       undergraduate            3.0
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df.dtypes
# Out:
# Unnamed: 0                                                               int64
# Timestamp                                                               object
# Your Academic Stage                                                     object
# Peer pressure                                                          float64
# Academic pressure from your home                                       float64
# Study Environment                                                       object
# What coping strategy you use as a student?                              object
# Do you have any bad habits like smoking, drinking on a daily basis?     object
# What would you rate the academic  competition in your student life     float64
# Rate your academic stress index                                        float64
# dtype: object

# %%
df.dropna()
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate              4
# 1             1  24/07/2025 22:05:52       undergraduate              3
# 2             2  24/07/2025 22:06:39       undergraduate              1
# 3             3  24/07/2025 22:06:45       undergraduate              3
# 4             4  24/07/2025 22:08:06       undergraduate              3
# ..          ...                  ...                 ...            ...
# 135         135  17/08/2025 13:02:04       undergraduate              3
# 136         136  18/08/2025 14:36:00       undergraduate              4
# 137         137  18/08/2025 17:13:52       undergraduate              3
# 138         138  18/08/2025 19:08:52       undergraduate              4
# 139         139  18/08/2025 22:40:13       undergraduate              4
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df["Peer pressure"]=df["Peer pressure"].astype("int")
df.head(5)
# Out:
#    Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0           0  24/07/2025 22:05:39       undergraduate              4
# 1           1  24/07/2025 22:05:52       undergraduate              3
# 2           2  24/07/2025 22:06:39       undergraduate              1
# 3           3  24/07/2025 22:06:45       undergraduate              3
# 4           4  24/07/2025 22:08:06       undergraduate              3
#
#    Academic pressure from your home Study Environment  \
# 0                               2.5             Noisy
# 1                               2.0          Peaceful
# 2                               0.5          Peaceful
# 3                               1.0          Peaceful
# 4                               1.5          Peaceful
#
#           What coping strategy you use as a student?  \
# 0  Analyze the situation and handle it with intel...
# 1  Analyze the situation and handle it with intel...
# ...

# %%
import pandas as pd 
path = "C:/Users/PRAKHAR/AppData/Local/Programs/Kaggle/academic-Stress-level.xlsx"
df = pd.read_excel(path)
print(df)
# Out:
#      Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0             0  24/07/2025 22:05:39       undergraduate            4.0
# 1             1  24/07/2025 22:05:52       undergraduate            3.0
# 2             2  24/07/2025 22:06:39       undergraduate            1.0
# 3             3  24/07/2025 22:06:45       undergraduate            3.0
# 4             4  24/07/2025 22:08:06       undergraduate            3.0
# ..          ...                  ...                 ...            ...
# 136         136  18/08/2025 14:36:00       undergraduate            4.0
# 137         137  18/08/2025 17:13:52       undergraduate            3.0
# 138         138  18/08/2025 19:08:52       undergraduate            4.0
# 139         139  18/08/2025 22:40:13       undergraduate            4.0
# 140         140  18/08/2025 22:40:14       undergraduate            NaN
#
#      Academic pressure from your home Study Environment  \
# ...

# %%
df=df.dropna()

# %%
df["Peer pressure"]=df["Peer pressure"].astype("int")
df.head(5)
# Out:
#    Unnamed: 0            Timestamp Your Academic Stage  Peer pressure  \
# 0           0  24/07/2025 22:05:39       undergraduate              4
# 1           1  24/07/2025 22:05:52       undergraduate              3
# 2           2  24/07/2025 22:06:39       undergraduate              1
# 3           3  24/07/2025 22:06:45       undergraduate              3
# 4           4  24/07/2025 22:08:06       undergraduate              3
#
#    Academic pressure from your home Study Environment  \
# 0                               5.0             Noisy
# 1                               4.0          Peaceful
# 2                               1.0          Peaceful
# 3                               2.0          Peaceful
# 4                               3.0          Peaceful
#
#           What coping strategy you use as a student?  \
# 0  Analyze the situation and handle it with intel...
# 1  Analyze the situation and handle it with intel...
# ...
